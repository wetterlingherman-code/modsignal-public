# %%
import pandas as pd


df1 = pd.read_json("../data/raw/r:Sverige comments.json")
df2 = pd.read_json("../data/raw/r:sverige posts search.json")
df3 = pd.read_json("../data/raw/r:Svenskpolitik comments.json")
df4 = pd.read_json("../data/raw/r:Svenskpolitik post search.json")


df = pd.concat([df1, df2, df3, df4])


print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/group-project-tiveden/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:948, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     947 try:
# --> 948     self.handles = get_handle(
#     949         filepath_or_buffer,
#     950         "r",
#     951         encoding=self.encoding,
#     952         compression=self.compression,
#     953         storage_options=self.storage_options,
#     954         errors=self.encoding_errors,
#     955     )
#     956 except OSError as err:
#
# File ~/Desktop/group-project-tiveden/.venv/lib/python3.13/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     924 if ioargs.encoding and "b" not in ioargs.mode:
#     925     # Encoding
# --> 926     handle = open(
# ...
